# %%
import pandas

# %%
# !pip install ffmpeg-python
# !pip install librosa==0.9.1
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 213.1/213.1 kB 2.1 MB/s eta 0:00:00a 0:00:01m
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 22.5 MB/s eta 0:00:00a 0:00:01
# ...
#   Attempting uninstall: librosa
#     Found existing installation: librosa 0.10.2.post1
#     Uninstalling librosa-0.10.2.post1:
#       Successfully uninstalled librosa-0.10.2.post1
# ...

# %%
# !git clone https://github.com/zabique/Wav2Lip
# Out:
# Cloning into 'Wav2Lip'...
# remote: Enumerating objects: 378, done.
# remote: Total 378 (delta 0), reused 0 (delta 0), pack-reused 378 (from 1)
# Receiving objects: 100% (378/378), 526.98 KiB | 3.31 MiB/s, done.
# Resolving deltas: 100% (205/205), done.

# %%
 '/content/Wav2Lip/checkpoints/wav2lip_gan.pth'
# Out:
# '/content/Wav2Lip/checkpoints/wav2lip_gan.pth'

# %%
# !wget 'https://iiitaphyd-my.sharepoint.com/personal/radrabha_m_research_iiit_ac_in/_layouts/15/download.aspx?share=EdjI7bZlgApMqsVoEUUXpLsBxqXbn5z8VTmoxp55YNDcIA' -O '/kaggle/working/Wav2Lip/checkpoints/wav2lip_gan.pth'
# Out:
# --2024-08-16 12:39:36--  https://iiitaphyd-my.sharepoint.com/personal/radrabha_m_research_iiit_ac_in/_layouts/15/download.aspx?share=EdjI7bZlgApMqsVoEUUXpLsBxqXbn5z8VTmoxp55YNDcIA
# Resolving iiitaphyd-my.sharepoint.com (iiitaphyd-my.sharepoint.com)... 13.107.136.10, 13.107.138.10, 2620:1ec:8f8::10, ...
# Connecting to iiitaphyd-my.sharepoint.com (iiitaphyd-my.sharepoint.com)|13.107.136.10|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 435801865 (416M) [application/octet-stream]
# Saving to: '/kaggle/working/Wav2Lip/checkpoints/wav2lip_gan.pth'
#
# /kaggle/working/Wav 100%[===================>] 415.61M   104MB/s    in 5.7s
#
# 2024-08-16 12:39:42 (72.4 MB/s) - '/kaggle/working/Wav2Lip/checkpoints/wav2lip_gan.pth' saved [435801865/435801865]

# %%
# !pip install https://raw.githubusercontent.com/AwaleSajil/ghc/master/ghc-1.0-py3-none-any.whl

# %%
# !wget "https://www.adrianbulat.com/downloads/python-fan/s3fd-619a316812.pth" -O "/kaggle/working/Wav2Lip/face_detection/detection/sfd/s3fd.pth"
# Out:
# --2024-08-16 12:39:56--  https://www.adrianbulat.com/downloads/python-fan/s3fd-619a316812.pth
# Resolving www.adrianbulat.com (www.adrianbulat.com)... 45.136.29.207
# Connecting to www.adrianbulat.com (www.adrianbulat.com)|45.136.29.207|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 89843225 (86M) [application/octet-stream]
# Saving to: '/kaggle/working/Wav2Lip/face_detection/detection/sfd/s3fd.pth'
#
# /kaggle/working/Wav 100%[===================>]  85.68M  23.8MB/s    in 3.6s
#
# 2024-08-16 12:40:00 (23.8 MB/s) - '/kaggle/working/Wav2Lip/face_detection/detection/sfd/s3fd.pth' saved [89843225/89843225]

# %%
# !cd Wav2Lip && pip install -r requirements.txt

# %%
# !wget "https://www.adrianbulat.com/downloads/python-fan/s3fd-619a316812.pth" -O "/kaggle/working/Wav2Lip/face_detection/detection/sfd/s3fd.pth"
# Out:
# --2024-08-16 12:40:13--  https://www.adrianbulat.com/downloads/python-fan/s3fd-619a316812.pth
# Resolving www.adrianbulat.com (www.adrianbulat.com)... 45.136.29.207
# Connecting to www.adrianbulat.com (www.adrianbulat.com)|45.136.29.207|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 89843225 (86M) [application/octet-stream]
# Saving to: '/kaggle/working/Wav2Lip/face_detection/detection/sfd/s3fd.pth'
#
# /kaggle/working/Wav 100%[===================>]  85.68M  22.4MB/s    in 3.8s
#
# 2024-08-16 12:40:18 (22.4 MB/s) - '/kaggle/working/Wav2Lip/face_detection/detection/sfd/s3fd.pth' saved [89843225/89843225]

# %%
from IPython.display import HTML, Audio
# from google.colab.output import eval_js
from base64 import b64decode
import numpy as np
from scipy.io.wavfile import read as wav_read
import io
import ffmpeg

from IPython.display import clear_output
clear_output()

# !rm -rf /content/sample_data
# !mkdir /content/sample_data



#download the pretrained model


# !pip uninstall tensorflow tensorflow-gpu


#download pretrained model for face detection






print("\nDone")
# Out:
# Done

# %%
pip install bark
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.7/3.7 MB 10.7 MB/s eta 0:00:0000:010:01
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 61.1 MB/s eta 0:00:00:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.0/11.0 MB 57.5 MB/s eta 0:00:0000:010:01m
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.2/43.2 kB 2.3 MB/s eta 0:00:00
# ...
#   Created wheel for encodec: filename=encodec-0.1.1-py3-none-any.whl size=45759 sha256=4c280258cc45ec2719eca9b20d77e8694426ec69befcebe84187f724f1cb53b9
#   Stored in directory: /root/.cache/pip/wheels/fc/36/cb/81af8b985a5f5e0815312d5e52b41263237af07b977e6bcbf3
# Successfully built encodec
# ...
#   Attempting uninstall: botocore
#     Found existing installation: botocore 1.34.131
#     Uninstalling botocore-1.34.131:
#       Successfully uninstalled botocore-1.34.131
# ...

# %%
from bark import SAMPLE_RATE, generate_audio, preload_models
import soundfile as sf
import numpy as np

# download and load all models
preload_models()

# generate audio from text
text_prompt = """
     Hello, my name is kuldeep jeengar. And and I like pizza.
     But I also have other interests such as playing cricket.
"""
speech_array = generate_audio(text_prompt)

# Ensure the audio data is in the correct format (float32 between -1 and 1)
speech_array_float32 = speech_array.astype(np.float32)

# Save the audio as a .wav file
sf.write('output_audio.wav', speech_array_float32, SAMPLE_RATE)

print("Audio saved as output_audio.wav")
# Out:
# text_2.pt:   0%|          | 0.00/5.35G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/49.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/996k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.96M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/625 [00:00<?, ?B/s]
# coarse_2.pt:   0%|          | 0.00/3.93G [00:00<?, ?B/s]
# fine_2.pt:   0%|          | 0.00/3.74G [00:00<?, ?B/s]
# /opt/conda/lib/python3.10/site-packages/torch/nn/utils/weight_norm.py:30: UserWarning: torch.nn.utils.weight_norm is deprecated in favor of torch.nn.utils.parametrizations.weight_norm.
#   warnings.warn("torch.nn.utils.weight_norm is deprecated in favor of torch.nn.utils.parametrizations.weight_norm.")
# Downloading: "https://dl.fbaipublicfiles.com/encodec/v0/encodec_24khz-d7cc33bc.th" to /root/.cache/torch/hub/checkpoints/encodec_24khz-d7cc33bc.th
# 100%|██████████| 88.9M/88.9M [00:00<00:00, 142MB/s]
# ...
# 100%|██████████| 38/38 [00:31<00:00,  1.22it/s]
# ...

# %%
# !cd /kaggle/working/Wav2Lip && python /kaggle/working/Wav2Lip/inference.py --checkpoint_path /kaggle/working/Wav2Lip/checkpoints/wav2lip_gan.pth --face "/kaggle/input/after-after/after.mp4" --audio "/kaggle/input/audiolisted/audio.wav" --pads 0 20 0 0
# Out:
# Using cuda for inference.
# Reading video frames...
# Number of frames available for inference: 459
# /kaggle/working/Wav2Lip/audio.py:100: FutureWarning: Pass sr=16000, n_fft=800 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   return librosa.filters.mel(hp.sample_rate, hp.n_fft, n_mels=hp.num_mels,
# (80, 641)
# Length of mel chunks: 393
# ...
#   0%|                                                    | 0/25 [00:00<?, ?it/s]

# %%
import os
import base64
from IPython.display import HTML

def create_download_link(file_path, file_name):
    """Create a download link for a file."""
    if not os.path.exists(file_path):
        return f"File not found: {file_path}"
    
    with open(file_path, 'rb') as f:
        data = f.read()
    b64 = base64.b64encode(data).decode()
    
    download_link = f'<a href="data:application/octet-stream;base64,{b64}" download="{file_name}">Download {file_name}</a>'
    return HTML(download_link)

# Usage
file_path = '/kaggle/working/Wav2Lip/results/result_voice.mp4'
file_name = 'result_voice.mp4'

display(create_download_link(file_path, file_name))
